# %% [markdown]
# # Exploration Notebook
#
# Минимальный ноутбук для первичного анализа синтетических логов и результатов прототипа.

# %%
from pathlib import Path
import pandas as pd

project_root = Path.cwd().parent
raw_path = project_root / 'data' / 'raw' / 'synthetic_logs.csv'
results_path = project_root / 'results' / 'metrics_summary.csv'

raw_df = pd.read_csv(raw_path) if raw_path.exists() else pd.DataFrame()
metrics_df = pd.read_csv(results_path) if results_path.exists() else pd.DataFrame()

raw_df.head(), metrics_df
